# %% [markdown]
# # Parse the results of new clixo, output relevant files for cytoscape analysis

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pandas as pd
import random


# latex rendering of text in graphs
import matplotlib as mpl

from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

sns.set_style('white')

import sys
from IPython.display import display
% matplotlib inline

# %%
from ddot import Ontology

# %% [markdown]
# # Load the network genes

# %%
ASD_CHD_df = pd.read_excel('../data/supplemental_tables_200604.xlsx',sheet_name='Table S1',skiprows=1)

print(len(ASD_CHD_df))
ASD_CHD_df.index=ASD_CHD_df['gene']
ASD_CHD_df.head()
# Out:
# 844
#         gene  dual_phenotype_snv_indel_DECIPHERv9.25  \
# gene
# NAA15  NAA15                                     0.0
# PTEN    PTEN                                     1.0
# POGZ    POGZ                                     3.0
# KMT2C  KMT2C                                     0.0
# KDM5B  KDM5B                                     1.0
#
#        dual_phenotype_snv_indel_DECIPHERv9.31  \
# gene
# NAA15                                     0.0
# PTEN                                      1.0
# POGZ                                      3.0
# KMT2C                                     0.0
# KDM5B                                     1.0
#
#        dual_phenotype_small_CNV_less1MB_DECIPHERv9.25  \
# gene
# NAA15                                             0.0
# PTEN                                              0.0
# POGZ                                              0.0
# KMT2C                                             0.0
# KDM5B                                             0.0
#
#        PCGC/PHN dual phenotype dDNV  \
# gene
# NAA15                           0.0
# PTEN                            1.0
# POGZ                            1.0
# KMT2C                           1.0
# KDM5B                           1.0
#
#        sum_damaging_variants (DECIPHER 9.25, PCGC/PHN)  ASD_HC  CHD_HC  \
# gene
# NAA15                                              0.0       1       1
# PTEN                                               2.0       1       1
# POGZ                                               4.0       1       1
# KMT2C                                              1.0       1       1
# KDM5B                                              2.0       1       1
#
#            z_ASD      z_CHD      z_both  gtex_heart_percentile_exp  \
# gene
# NAA15  18.901197  20.892283  394.889167                   0.733689
# PTEN   16.395135  18.819067  308.541142                   0.896062
# POGZ   14.186540  14.641398  207.710787                   0.908309
# KMT2C  13.462226  14.954173  201.316464                   0.873100
# KDM5B  10.464431  13.490241  141.167693                   0.677893
#
#        gtex_brain_percentile_exp
# gene
# NAA15                   0.620830
# PTEN                    0.894637
# POGZ                    0.953178
# KMT2C                   0.908995
# KDM5B                   0.698533

# %%
# where do shared phenotype dnvs fall within the ontology?
shared_DNV_genes = ASD_CHD_df[ASD_CHD_df['PCGC/PHN dual phenotype dDNV']==1].index.tolist()
print(len(shared_DNV_genes))

decipher_SNV_genes = ASD_CHD_df[ASD_CHD_df['dual_phenotype_snv_indel_DECIPHERv9.25']>0].index.tolist()
print(len(decipher_SNV_genes))

decipher_CNV_genes = ASD_CHD_df[ASD_CHD_df['dual_phenotype_small_CNV_less1MB_DECIPHERv9.25']>0].index.tolist()
print(len(decipher_CNV_genes))
all_val_genes = list(np.unique(shared_DNV_genes+decipher_SNV_genes+decipher_CNV_genes))
print(len(all_val_genes))
# Out:
# 44
# 78
# 98
# 174

# %% [markdown]
# # Load PCnet
#
# Download PCnet from https://ndexbio.org/#/network/f93f402c-86d4-11e7-a10d-0ac135e8bacf (UUID: f93f402c-86d4-11e7-a10d-0ac135e8bacf)

# %%
G_pcnet = nx.read_gpickle('/Users/brinrosenthal/Documents/CCBB_tickets_data/PCnet/G_PCnet.gpickle')

print(len(G_pcnet.nodes()))
print(len(G_pcnet.edges()))
# Out:
# 19781
# 2724724

# %%
# make a subgraph from ASD_CHD_df genes
G_ASD_CHD = nx.subgraph(G_pcnet,ASD_CHD_df.index.tolist())
print(len(G_ASD_CHD.nodes()))
print(len(G_ASD_CHD.edges()))
# Out:
# 844
# 28559

# %% [markdown]
# # Load similarity matrix

# %%
sim_rank_EL = pd.read_csv('new_clixo_files/sim_rank_cosine_EL.tsv',sep='\t',names=['node1','node2','sim'])
sim_rank_EL.head()
# Out:
#      node1     node2       sim
# 0  SMARCC2  HIST1H4B  0.981613
# 1  SMARCC2   ZCCHC11  0.760676
# 2  SMARCC2   SMARCC1  1.000000
# 3  SMARCC2   ZDHHC12  0.212930
# 4  SMARCC2  HIST1H4J  0.983393

# %% [markdown]
# # Read in the ontology

# %%
alpha='01'
beta='45'
filepath='new_clixo_files/ASDCHD.cosine..'+alpha+'..'+beta+'.ont'

# %%
ont = Ontology.from_table('new_clixo_files/ASDCHD_parsed_alpha.cosine.'+alpha+'_beta_.'+beta+'.txt',parent=0,child=1)
# Out:
# /Users/brinrosenthal/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/ddot/Ontology.py:1606: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   table = pd.read_table(table, comment='#', header=header)

# %%
ont
# Out:
# 844 genes, 120 terms, 2270 gene-term relations, 133 term-term relations
# node_attributes: []
# edge_attributes: ['Gene-Term']

# %% [markdown]
# # Add the fraction validated genes to ontology terms, write out for input to cytoscape

# %%
term_sizes = pd.Series(ont.term_sizes)
term_sizes.index = pd.Series(ont.terms_index).index.tolist()
term_sizes=term_sizes.sort_values(ascending=False)
term_sizes.head()
# Out:
# 963    844
# 962    344
# 961    324
# 960    302
# 959    240
# dtype: int64

# %%
# need to use ont_connected to get actual genes in term (trace ontology)

ont_connected = pd.DataFrame(ont.connected())
ont_connected.index=pd.Series(ont.genes_index).index.tolist()+pd.Series(ont.terms_index).index.tolist()
ont_connected.columns=pd.Series(ont.genes_index).index.tolist()+pd.Series(ont.terms_index).index.tolist()
ont_connected.head()
# Out:
#             AC008575.1  AC067968.1   ACHE   ACTB  ACTN2  ACTN4  ADAM17  \
# AC008575.1        True       False  False  False  False  False   False
# AC067968.1       False        True  False  False  False  False   False
# ACHE             False       False   True  False  False  False   False
# ACTB             False       False  False   True  False  False   False
# ACTN2            False       False  False  False   True  False   False
#
#             ADGRL2   ADNP   AFDN  ...    954    955    956    957    958  \
# AC008575.1   False  False  False  ...  False   True  False  False   True
# AC067968.1   False  False  False  ...  False  False  False  False  False
# ACHE         False  False  False  ...  False  False  False  False   True
# ACTB         False  False  False  ...   True  False  False   True  False
# ACTN2        False  False  False  ...  False  False  False  False   True
#
#               959    960    961    962   963
# AC008575.1  False   True   True   True  True
# AC067968.1  False  False  False  False  True
# ACHE        False  False   True  False  True
# ACTB        False   True  False   True  True
# ACTN2       False   True   True  False  True
#
# [5 rows x 964 columns]

# %%
gene2term_full = ont_connected.iloc[0:len(ont.genes_index)].T.iloc[len(ont.genes_index):].T
gene2term_full.head()
# Out:
#               844    845    846    847    848    849    850    851    852  \
# AC008575.1  False  False  False   True  False  False  False  False  False
# AC067968.1  False  False  False  False  False  False  False  False  False
# ACHE        False  False  False  False  False  False  False  False  False
# ACTB        False  False  False  False  False  False  False  False  False
# ACTN2       False  False  False  False  False  False  False  False   True
#
#               853  ...    954    955    956    957    958    959    960  \
# AC008575.1  False  ...  False   True  False  False   True  False   True
# AC067968.1  False  ...  False  False  False  False  False  False  False
# ACHE        False  ...  False  False  False  False   True  False  False
# ACTB        False  ...   True  False  False   True  False  False   True
# ACTN2       False  ...  False  False  False  False   True  False   True
#
#               961    962   963
# AC008575.1   True   True  True
# AC067968.1  False  False  True
# ACHE         True  False  True
# ACTB        False   True  True
# ACTN2        True  False  True
#
# [5 rows x 120 columns]

# %%
# save out the pathways which have at least one validated xenopus gene
xenopus_validated_genes=['CREBBP','KAT6A','KANSL1','NSD1','KMT2D',
                        'ANKRD11','PTPN11','SCN2A']
xenopus_pathways = gene2term_full.loc[xenopus_validated_genes]
# xenopus_pathways.sum().sort_values(ascending=False).to_csv('new_clixo_files/xenopus_validated_pathways.tsv',sep='\t')

# %%
# write out the gene2term matrix
# gene2term_full.to_csv('new_clixo_files/gene2term_full_'+alpha+'_'+beta+'.csv')

# %%
ont2numVal = pd.DataFrame(columns=['term','num_shared_DNV','num_DECIPHER_SNV','num_DECIPHER_CNV','all_val_genes','cluster_size'])
genes_index= pd.Series(ont.genes_index)

for focal_term in ont.term_2_gene.keys():
    focal_genes=gene2term_full[gene2term_full[focal_term]].index.tolist()     
    
    shared_DNV_temp = len(np.intersect1d(focal_genes,shared_DNV_genes))
    DECIPHER_SNV_temp = len(np.intersect1d(focal_genes,decipher_SNV_genes))
    DECIPHER_CNV_temp = len(np.intersect1d(focal_genes,decipher_CNV_genes))
    allVal_temp = len(np.intersect1d(focal_genes,all_val_genes))
    ont2numVal = ont2numVal.append(pd.DataFrame({'term':[focal_term],'num_shared_DNV':[shared_DNV_temp],
                                                'num_DECIPHER_SNV':[DECIPHER_SNV_temp],'num_DECIPHER_CNV':[DECIPHER_CNV_temp],
                                                'all_val_genes':[allVal_temp],'cluster_size':[len(focal_genes)]}),ignore_index=True)




ont2numVal['fractionVal']=ont2numVal['all_val_genes']/ont2numVal['cluster_size']
ont2numVal = ont2numVal.sort_values('fractionVal',ascending=False)
ont2numVal.index=ont2numVal['term']
ont2numVal.head()
# Out:
# /Users/brinrosenthal/anaconda3/envs/ipykernel_py2/lib/python2.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#      all_val_genes cluster_size num_DECIPHER_CNV num_DECIPHER_SNV  \
# term
# 886              9           17                4                4
# 920             19           37                5               13
# 892              9           18                3                7
# 853              4            9                2                4
# 852              4            9                2                2
#
#      num_shared_DNV term fractionVal
# term
# 886               3  886    0.529412
# 920               9  920    0.513514
# 892               3  892         0.5
# 853               2  853    0.444444
# 852               2  852    0.444444

# %%
# ont2numVal.to_csv('new_clixo_no_alignment/ont2numVal_cosine_alpha'+alpha+'_beta'+beta+'.txt',sep='\t')

# %% [markdown]
# # Run enrichment on each cluster, after discussion with Trey
#
# Enrich each term separately, using gprofiler
#
# Also run GO alignment, but this happens in a separate notebook (clixo_GO_alignment/ASD_CHD_new_clixo_cosine_GO_alignment_200428.ipynb)

# %%
from gprofiler import GProfiler
gp = GProfiler("MyToolName/0.1")

# %%
# loop over terms in gene2term_full
gene2term_full.head()
# Out:
#               844    845    846    847    848    849    850    851    852  \
# AC008575.1  False  False  False   True  False  False  False  False  False
# AC067968.1  False  False  False  False  False  False  False  False  False
# ACHE        False  False  False  False  False  False  False  False  False
# ACTB        False  False  False  False  False  False  False  False  False
# ACTN2       False  False  False  False  False  False  False  False   True
#
#               853  ...    954    955    956    957    958    959    960  \
# AC008575.1  False  ...  False   True  False  False   True  False   True
# AC067968.1  False  ...  False  False  False  False  False  False  False
# ACHE        False  ...  False  False  False  False   True  False  False
# ACTB        False  ...   True  False  False   True  False  False   True
# ACTN2       False  ...  False  False  False  False   True  False   True
#
#               961    962   963
# AC008575.1   True   True  True
# AC067968.1  False  False  True
# ACHE         True  False  True
# ACTB        False   True  True
# ACTN2        True  False  True
#
# [5 rows x 120 columns]

# %%
import os

savedir_profile = 'gprofiler_clixo_ASD_CHD_cosine_alpha_'+alpha+'_beta_'+beta
if not os.path.isdir(savedir_profile):
    os.mkdir(savedir_profile)

cluster2top_pathway = pd.DataFrame(columns=['cluster','pathway','term_ID',
                                            'term_p-value','term_recall','term_precision','num_genes_in_cluster'])

for focal_cluster in gene2term_full.columns.tolist():
    print(focal_cluster)
    focal_genes = gene2term_full[gene2term_full[focal_cluster]].index.tolist()
    print(len(focal_genes))
    if len(focal_genes)>5: # only run enrichment if > 5 genes in cluster
        # ---- USE THIS FOR BACKGROUND OF all PCnet genes ----
        gp_results = pd.DataFrame(gp.gprofile(focal_genes,custom_bg = G_pcnet.nodes(),correction_method=gp.THR_FDR))
        
        # ---- USE THIS FOR BACKGROUND OF 844 ASDCHD genes ----
        # gp_results = pd.DataFrame(gp.gprofile(focal_genes,custom_bg = gene2term_full.index.tolist(),correction_method=gp.THR_FDR))
        
        if len(gp_results)>0: # make sure there are some significant enrichments

            gp_results.columns = ["query.number", "significant", "p.value", "term.size",
                                  "query.size", "overlap.size", "recall", "precision",
                                  "term.id", "domain", "subgraph.number", "term.name",
                                  "relative.depth", "intersection"]
            print(gp_results[['p.value','precision','recall','term.size','overlap.size','term.id','term.name']].head())

            # uncomment if we want to save the results
            writer = pd.ExcelWriter(savedir_profile+'/cluster_'+str(focal_cluster)+'.xlsx')
            gp_results.to_excel(writer)
            writer.save()

            cluster2top_pathway = cluster2top_pathway.append(pd.DataFrame({'cluster':[focal_cluster],
                                                                          'pathway':gp_results.loc[0]['term.name'],
                                                                           'term_ID':gp_results.loc[0]['term.id'],
                                                                          'term_p-value':gp_results.loc[0]['p.value'],
                                                                           'term_recall':gp_results.loc[0]['recall'],
                                                                           'term_precision':gp_results.loc[0]['precision'],
                                                                          'num_genes_in_cluster':[len(focal_genes)]}),
                                                            ignore_index=True)
            
        else:
            
            cluster2top_pathway = cluster2top_pathway.append(pd.DataFrame({'cluster':[focal_cluster],
                                                                      'pathway':'None',
                                                                       'term_ID':'None',
                                                                      'term_p-value':1.0,
                                                                        'term_recall':'None',
                                                                        'term_precision':'None',
                                                                      'num_genes_in_cluster':[len(focal_genes)]}),
                                                        ignore_index=True)
            
    else:
        cluster2top_pathway = cluster2top_pathway.append(pd.DataFrame({'cluster':[focal_cluster],
                                                                      'pathway':'None',
                                                                       'term_ID':'None',
                                                                      'p-value':1.0,
                                                                        'term_recall':'None',
                                                                        'term_precision':'None',
                                                                      'num_genes_in_cluster':[len(focal_genes)]}),
                                                        ignore_index=True)

#gp_results = pd.DataFrame(gp.gprofile(focal_genes,correction_method=gp.THR_FDR))
# Out:
# 844
# 6
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.820000e-13      0.357   0.833         14             5
# 1  8.960000e-13      0.172   1.000         29             5
# 2  9.260000e-13      0.238   0.833         21             5
# 3  1.020000e-12      0.217   0.833         23             5
# 4  4.100000e-12      0.114   1.000         44             5
#
#               term.id                              term.name
# 0          GO:0001518   voltage-gated sodium channel complex
# 1   REAC:R-HSA-445095    Interaction between L1 and Ankyrins
# 2          GO:0034706                 sodium channel complex
# 3          GO:0005248  voltage-gated sodium channel activity
# 4  REAC:R-HSA-5576892         Phase 0 - rapid depolarisation
# 845
# 7
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0   0.0271        0.2   0.333          5             1  REAC:R-HSA-5624138
#
#                                            term.name
# 0  Trafficking of myristoylated proteins to the c...
# 846
# 7
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  2.150000e-16      0.149     1.0         47             7  GO:0018024
# 1  4.200000e-16      0.113     1.0         62             7  GO:0016278
# 2  4.200000e-16      0.119     1.0         59             7  GO:0042054
# 3  4.200000e-16      0.115     1.0         61             7  GO:0016279
# 4  4.330000e-15      0.080     1.0         88             7  GO:0008276
#
#                                      term.name
# 0  histone-lysine N-methyltransferase activity
# 1          lysine N-methyltransferase activity
# 2           histone methyltransferase activity
# 3  protein-lysine N-methyltransferase activity
# 4           protein methyltransferase activity
# 847
# 8
#    p.value  precision  recall  term.size  overlap.size                term.id  \
# 0   0.0270      0.030   0.400         67             2  MIRNA:hsa-miR-6789-3p
# 1   0.0430      0.006   1.000        154             1             KEGG:04934
# 2   0.0443      0.024   0.333         83             2             GO:0008013
# 3   0.0443      0.006   0.500        510             3             GO:0005912
# 4   0.0443      0.006   0.500        527             3             GO:0070161
#
#               term.name
# 0       hsa-miR-6789-3p
# 1      Cushing syndrome
# 2  beta-catenin binding
# 3     adherens junction
# 4    anchoring junction
# 848
# 8
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0   0.0314      0.005     1.0        183             1  REAC:R-HSA-6811442
# 1   0.0314      0.024     1.0         42             1   REAC:R-HSA-983189
# 2   0.0314      0.006     1.0        154             1   REAC:R-HSA-983231
# 3   0.0314      0.009     1.0        115             1  REAC:R-HSA-8856688
# 4   0.0314      0.012     1.0         81             1  REAC:R-HSA-6811434
#
#                                            term.name
# 0     Intra-Golgi and retrograde Golgi-to-ER traffic
# 1                                           Kinesins
# 2  Factors involved in megakaryocyte development ...
# 3                   Golgi-to-ER retrograde transport
# 4      COPI-dependent Golgi-to-ER retrograde traffic
# 849
# 9
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000927      0.004   0.778       1640             7  GO:0003723
# 1  0.003560      0.028   0.333        109             3  GO:0071427
# 2  0.003560      0.023   0.333        128             3  GO:0071166
# 3  0.003560      0.024   0.333        127             3  GO:0071426
# 4  0.003560      0.028   0.333        109             3  GO:0006406
#
#                                            term.name
# 0                                        RNA binding
# 1  mRNA-containing ribonucleoprotein complex expo...
# 2             ribonucleoprotein complex localization
# 3      ribonucleoprotein complex export from nucleus
# 4                           mRNA export from nucleus
# 850
# 9
#     p.value  precision  recall  term.size  overlap.size             term.id  \
# 0  0.000002      0.667    1.00          3             2          CORUM:6527
# 1  0.002500      0.500    0.50          2             1          CORUM:6529
# 2  0.002500      0.333    0.50          3             1          CORUM:6528
# 3  0.034600      0.100    0.25         10             1   REAC:R-HSA-418886
# 4  0.034600      0.077    0.25         13             1  REAC:R-HSA-5140745
#
#                                            term.name
# 0                          FLRT3-LPHN3-UNC5B complex
# 1                                FLRT3-LPHN3 complex
# 2                          FLRT3-LPHN3-UNC5D complex
# 3                  Netrin mediated repulsion signals
# 4  WNT5A-dependent internalization of FZD2, FZD5 ...
# 851
# 9
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.380000e-15      0.500   0.667         12             6
# 1  1.380000e-15      0.226   0.778         31             7
# 2  3.190000e-14      0.121   0.778         58             7
# 3  3.190000e-14      0.121   0.778         58             7
# 4  3.190000e-14      0.273   0.667         22             6
#
#               term.id                                          term.name
# 0  REAC:R-HSA-1980150                                Signaling by NOTCH4
# 1  REAC:R-HSA-2122948   Activated NOTCH1 Transmits Signal to the Nucleus
# 2  REAC:R-HSA-2894862  Constitutive Signaling by NOTCH1 HD+PEST Domai...
# 3  REAC:R-HSA-2894858  Signaling by NOTCH1 HD+PEST Domain Mutants in ...
# 4  REAC:R-HSA-2979096  NOTCH2 Activation and Transmission of Signal t...
# 852
# 9
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.120000e-14      0.353   0.667         17             6
# 1  1.120000e-14      0.353   0.667         17             6
# 2  1.120000e-14      0.400   0.667         15             6
# 3  2.000000e-13      0.222   0.667         27             6
# 4  8.760000e-13      0.171   0.667         35             6
#
#              term.id                                          term.name
# 0  REAC:R-HSA-442982  Ras activation upon Ca2+ influx through NMDA r...
# 1  REAC:R-HSA-438066  Unblocking of NMDA receptor, glutamate binding...
# 2  REAC:R-HSA-442729  CREB phosphorylation through the activation of...
# 3  REAC:R-HSA-442742  CREB phosphorylation through the activation of...
# 4  REAC:R-HSA-438064               Post NMDA receptor activation events
# 853
# 9
#         p.value  precision  recall  term.size  overlap.size  \
# 0  3.450000e-10      0.012   1.000        768             9
# 1  6.730000e-09      0.008   1.000       1152             9
# 2  5.820000e-08      0.015   0.778        456             7
# 3  4.300000e-07      0.022   0.750        274             6
# 4  4.300000e-07      0.022   0.750        274             6
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2          GO:0016569  covalent chromatin modification
# 3  REAC:R-HSA-4839726           Chromatin organization
# 4  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 854
# 10
#     p.value  precision  recall  term.size  overlap.size            term.id  \
# 0  0.000052      0.103   0.375         29             3  REAC:R-HSA-445095
# 1  0.000088      0.011   0.600        538             6         GO:0030424
# 2  0.000148      0.006   0.700       1155             7         GO:0043005
# 3  0.000331      0.024   0.400        167             4         GO:0035637
# 4  0.000378      0.005   0.700       1468             7         GO:0097458
#
#                              term.name
# 0  Interaction between L1 and Ankyrins
# 1                                 axon
# 2                    neuron projection
# 3   multicellular organismal signaling
# 4                          neuron part
# 855
# 10
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000058      0.007   0.778       1053             7  GO:0048666
# 1  0.000075      0.004   0.889       2012             8  GO:0048468
# 2  0.000079      0.097   0.333         31             3  GO:1902803
# 3  0.000079      0.005   0.778       1303             7  GO:0030182
# 4  0.000081      0.004   0.889       2281             8  GO:0007399
#
#                                   term.name
# 0                        neuron development
# 1                          cell development
# 2  regulation of synaptic vesicle transport
# 3                    neuron differentiation
# 4                nervous system development
# 856
# 10
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.030000e-11      0.185   0.625         27             5  GO:0032452
# 1  4.030000e-11      0.161   0.625         31             5  GO:0006482
# 2  4.030000e-11      0.161   0.625         31             5  GO:0008214
# 3  4.030000e-11      0.185   0.625         27             5  GO:0070076
# 4  4.030000e-11      0.172   0.625         29             5  GO:0016577
#
#                       term.name
# 0  histone demethylase activity
# 1         protein demethylation
# 2          protein dealkylation
# 3  histone lysine demethylation
# 4         histone demethylation
# 857
# 10
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0  0.00173      0.039   0.667         51             2  REAC:R-HSA-6802949
# 1  0.00183      0.027   0.667         74             2  REAC:R-HSA-6802957
# 2  0.01000      0.008   0.667        239             2  REAC:R-HSA-5673001
# 3  0.01000      0.008   0.667        245             2  REAC:R-HSA-5684996
# 4  0.01070      0.007   0.667        284             2  REAC:R-HSA-5683057
#
#                         term.name
# 0        Signaling by RAS mutants
# 1        Oncogenic MAPK signaling
# 2          RAF/MAP kinase cascade
# 3           MAPK1/MAPK3 signaling
# 4  MAPK family signaling cascades
# 858
# 10
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  5.880000e-28      0.370     1.0         27            10  GO:0019706
# 1  5.880000e-28      0.370     1.0         27            10  GO:0019707
# 2  2.060000e-27      0.323     1.0         31            10  GO:0016417
# 3  1.650000e-26      0.263     1.0         38            10  GO:0016409
# 4  3.510000e-24      0.321     0.9         28             9  GO:0018345
#
#                                           term.name
# 0  protein-cysteine S-palmitoyltransferase activity
# 1       protein-cysteine S-acyltransferase activity
# 2                        S-acyltransferase activity
# 3                     palmitoyltransferase activity
# 4                            protein palmitoylation
# 859
# 10
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.170000e-25      0.345     1.0         29            10
# 1  5.050000e-20      0.100     1.0        100            10
# 2  6.140000e-19      0.500     0.7         14             7
# 3  6.140000e-19      0.060     1.0        167            10
# 4  6.140000e-19      0.129     0.9         70             9
#
#              term.id                             term.name
# 0  REAC:R-HSA-445095   Interaction between L1 and Ankyrins
# 1  REAC:R-HSA-373760                    L1CAM interactions
# 2         GO:0001518  voltage-gated sodium channel complex
# 3         GO:0035637    multicellular organismal signaling
# 4         GO:0019226         transmission of nerve impulse
# 860
# 11
#         p.value  precision  recall  term.size  overlap.size  \
# 0  2.950000e-08      0.286   0.364         14             4
# 1  4.250000e-08      0.138   0.571         29             4
# 2  8.680000e-08      0.174   0.364         23             4
# 3  8.680000e-08      0.190   0.364         21             4
# 4  1.210000e-07      0.091   0.571         44             4
#
#               term.id                              term.name
# 0          GO:0001518   voltage-gated sodium channel complex
# 1   REAC:R-HSA-445095    Interaction between L1 and Ankyrins
# 2          GO:0005248  voltage-gated sodium channel activity
# 3          GO:0034706                 sodium channel complex
# 4  REAC:R-HSA-5576892         Phase 0 - rapid depolarisation
# 861
# 11
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000106      0.045   0.364         88             4  GO:0060996
# 1  0.000108      1.000   0.182          2             2  GO:0021816
# 2  0.000361      0.400   0.182          5             2  GO:0034334
# 3  0.000361      0.013   0.455        398             5  GO:0043547
# 4  0.000361      0.064   0.273         47             3  GO:0008347
#
#                                            term.name
# 0                        dendritic spine development
# 1  extension of a leading process involved in cel...
# 2                      adherens junction maintenance
# 3             positive regulation of GTPase activity
# 4                               glial cell migration
# 862
# 11
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.210000e-19      0.053   1.000        208            11  GO:0008168
# 1  1.210000e-19      0.050   1.000        218            11  GO:0016741
# 2  1.980000e-19      0.148   0.818         61             9  GO:0016279
# 3  1.980000e-19      0.145   0.818         62             9  GO:0016278
# 4  2.670000e-18      0.060   0.909        168            10  GO:0006479
#
#                                            term.name
# 0                         methyltransferase activity
# 1  transferase activity, transferring one-carbon ...
# 2        protein-lysine N-methyltransferase activity
# 3                lysine N-methyltransferase activity
# 4                                protein methylation
# 863
# 11
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000009      0.006   0.818       1468             9  GO:0097458
# 1  0.000024      0.007   0.727       1155             8  GO:0043005
# 2  0.000042      0.005   0.818       1980             9  GO:0042995
# 3  0.000046      0.008   0.636        853             7  GO:0045202
# 4  0.000148      0.016   0.455        305             5  GO:0050808
#
#               term.name
# 0           neuron part
# 1     neuron projection
# 2       cell projection
# 3               synapse
# 4  synapse organization
# 864
# 12
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000056      0.143    0.25         21             3  GO:0007413
# 1  0.000056      0.013    0.50        475             6  GO:0061564
# 2  0.000056      0.014    0.50        438             6  GO:0007409
# 3  0.000056      0.143    0.25         21             3  GO:0106030
# 4  0.000088      0.011    0.50        549             6  GO:0048667
#
#                                            term.name
# 0                               axonal fasciculation
# 1                                   axon development
# 2                                       axonogenesis
# 3                    neuron projection fasciculation
# 4  cell morphogenesis involved in neuron differen...
# 865
# 12
#     p.value  precision  recall  term.size  overlap.size            term.id  \
# 0  0.000002      0.667   1.000          3             2         CORUM:6527
# 1  0.000377      0.200   0.286         10             2  REAC:R-HSA-418889
# 2  0.000377      0.200   0.286         10             2  REAC:R-HSA-418886
# 3  0.000442      0.017   0.750        174             3         KEGG:04360
# 4  0.001690      0.018   0.333        226             4         GO:0007411
#
#                                        term.name
# 0                      FLRT3-LPHN3-UNC5B complex
# 1  Ligand-independent caspase activation via DCC
# 2              Netrin mediated repulsion signals
# 3                                  Axon guidance
# 4                                  axon guidance
# 866
# 12
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.080000e-10      0.105     0.5         57             6  GO:0043966
# 1  7.450000e-10      0.455     0.5         11             5  CORUM:2859
# 2  1.220000e-09      0.079     0.5         76             6  GO:0000123
# 3  1.310000e-09      0.070     0.5         86             6  GO:0031248
# 4  1.310000e-09      0.070     0.5         86             6  GO:1902493
#
#                            term.name
# 0             histone H3 acetylation
# 1                       ING5 complex
# 2  histone acetyltransferase complex
# 3  protein acetyltransferase complex
# 4          acetyltransferase complex
# 867
# 13
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0  0.00688      0.039     0.4         51             2  REAC:R-HSA-6802949
# 1  0.00726      0.027     0.4         74             2  REAC:R-HSA-6802957
# 2  0.03200      0.062     0.2         16             1    REAC:R-HSA-70221
# 3  0.03200      0.048     0.2         21             1   REAC:R-HSA-373753
# 4  0.03200      0.008     0.4        239             2  REAC:R-HSA-5673001
#
#                              term.name
# 0             Signaling by RAS mutants
# 1             Oncogenic MAPK signaling
# 2  Glycogen breakdown (glycogenolysis)
# 3          Nephrin family interactions
# 4               RAF/MAP kinase cascade
# 868
# 13
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.00119      0.002   0.923       5740            12  GO:0006139
# 1  0.00119      0.002   0.923       5126            12  GO:0090304
# 2  0.00119      0.333   0.154          6             2  GO:0070087
# 3  0.00119      0.002   0.846       4633            11  GO:0016070
# 4  0.00119      0.006   0.538       1152             7  GO:0051276
#
#                                           term.name
# 0  nucleobase-containing compound metabolic process
# 1                    nucleic acid metabolic process
# 2                      chromo shadow domain binding
# 3                             RNA metabolic process
# 4                           chromosome organization
# 869
# 13
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.00562      0.333   0.333          3             1  CORUM:2767
# 1  0.00562      0.500   0.333          2             1   CORUM:263
# 2  0.00562      0.333   0.333          3             1   CORUM:618
# 3  0.00562      0.333   0.333          3             1  CORUM:6192
# 4  0.00562      0.333   0.333          3             1   CORUM:972
#
#                                term.name
# 0      RAD50-MRE11-NBN-p200-p350 complex
# 1      R/M complex (RAD50-MRE11 complex)
# 2  MRN complex (MRE11-RAD50-NBN complex)
# 3            CHDH-SQSTM1-MAP1LC3 complex
# 4  MRN complex (MRE11-RAD50-NBN complex)
# 870
# 13
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.060000e-08      0.038   0.462        158             6  GO:0006475
# 1  4.060000e-08      0.041   0.462        148             6  GO:0016573
# 2  4.060000e-08      0.079   0.385         63             5  GO:0140034
# 3  4.060000e-08      0.012   0.692        768             9  GO:0006325
# 4  4.060000e-08      0.079   0.385         63             5  GO:0035064
#
#                                  term.name
# 0  internal protein amino acid acetylation
# 1                      histone acetylation
# 2    methylation-dependent protein binding
# 3                   chromatin organization
# 4               methylated histone binding
# 871
# 13
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  2.910000e-25      0.370   0.769         27            10  GO:0019707
# 1  2.910000e-25      0.370   0.769         27            10  GO:0019706
# 2  1.020000e-24      0.323   0.769         31            10  GO:0016417
# 3  8.130000e-24      0.263   0.769         38            10  GO:0016409
# 4  4.340000e-22      0.321   0.692         28             9  GO:0018345
#
#                                           term.name
# 0       protein-cysteine S-acyltransferase activity
# 1  protein-cysteine S-palmitoyltransferase activity
# 2                        S-acyltransferase activity
# 3                     palmitoyltransferase activity
# 4                            protein palmitoylation
# 872
# 14
#         p.value  precision  recall  term.size  overlap.size  \
# 0  9.610000e-15      0.017   0.929        768            13
# 1  9.480000e-13      0.011   0.929       1152            13
# 2  2.050000e-10      0.033   0.692        274             9
# 3  2.050000e-10      0.033   0.692        274             9
# 4  6.880000e-10      0.118   0.462         51             6
#
#               term.id                    term.name
# 0          GO:0006325       chromatin organization
# 1          GO:0051276      chromosome organization
# 2  REAC:R-HSA-3247509  Chromatin modifying enzymes
# 3  REAC:R-HSA-4839726       Chromatin organization
# 4  REAC:R-HSA-3214842    HDMs demethylate histones
# 873
# 14
#         p.value  precision  recall  term.size  overlap.size  \
# 0  5.180000e-30      0.132     1.0        106            14
# 1  7.660000e-30      0.123     1.0        114            14
# 2  1.490000e-29      0.192     1.0         73            14
# 3  9.120000e-29      0.163     1.0         86            14
# 4  1.210000e-28      0.156     1.0         90            14
#
#               term.id                                          term.name
# 0          GO:0000786                                         nucleosome
# 1          GO:0044815                              DNA packaging complex
# 2  REAC:R-HSA-2299718               Condensation of Prophase Chromosomes
# 3   REAC:R-HSA-912446                              Meiotic recombination
# 4   REAC:R-HSA-201722  Formation of the beta-catenin:TCF transactivat...
# 874
# 14
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.580000e-07      0.008   0.786       1441            11
# 1  1.580000e-07      0.007   0.786       1535            11
# 2  3.760000e-07      0.273   0.500         11             3
# 3  2.640000e-06      0.009   0.643       1051             9
# 4  5.490000e-06      0.005   0.786       2281            11
#
#              term.id                         term.name
# 0         GO:0048699             generation of neurons
# 1         GO:0022008                      neurogenesis
# 2  REAC:R-HSA-376172                DSCAM interactions
# 3         GO:0032989  cellular component morphogenesis
# 4         GO:0007399        nervous system development
# 875
# 14
#         p.value  precision  recall  term.size  overlap.size  \
# 0  2.820000e-14      0.500   0.500         12             6
# 1  2.820000e-14      0.226   0.583         31             7
# 2  7.380000e-13      0.121   0.583         58             7
# 3  7.380000e-13      0.121   0.583         58             7
# 4  7.380000e-13      0.273   0.500         22             6
#
#               term.id                                          term.name
# 0  REAC:R-HSA-1980150                                Signaling by NOTCH4
# 1  REAC:R-HSA-2122948   Activated NOTCH1 Transmits Signal to the Nucleus
# 2  REAC:R-HSA-2644603                      Signaling by NOTCH1 in Cancer
# 3  REAC:R-HSA-2644602  Signaling by NOTCH1 PEST Domain Mutants in Cancer
# 4  REAC:R-HSA-2979096  NOTCH2 Activation and Transmission of Signal t...
# 876
# 15
#         p.value  precision  recall  term.size  overlap.size  \
# 0  3.520000e-25      0.235   0.857         51            12
# 1  1.640000e-20      0.333   0.600         27             9
# 2  1.640000e-20      0.333   0.600         27             9
# 3  2.340000e-20      0.310   0.600         29             9
# 4  2.820000e-20      0.290   0.600         31             9
#
#               term.id                     term.name
# 0  REAC:R-HSA-3214842     HDMs demethylate histones
# 1          GO:0070076  histone lysine demethylation
# 2          GO:0032452  histone demethylase activity
# 3          GO:0016577         histone demethylation
# 4          GO:0008214          protein dealkylation
# 877
# 15
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  9.810000e-07      0.250   0.667         16             4  HP:0010819
# 1  1.400000e-05      0.114   0.667         35             4  HP:0002121
# 2  3.450000e-05      0.083   0.667         48             4  HP:0011146
# 3  2.530000e-04      0.048   0.667         84             4  HP:0002069
# 4  4.350000e-04      0.107   0.500         28             3  HP:0002373
#
#                            term.name
# 0                    Atonic seizures
# 1                   Absence seizures
# 2                 Dialeptic seizures
# 3  Generalized tonic-clonic seizures
# 4                   Febrile seizures
# 878
# 15
#    p.value  precision  recall  term.size  overlap.size            term.id  \
# 0  0.00125      0.333   1.000          3             1         CORUM:6528
# 1  0.00125      0.500   1.000          2             1         CORUM:6529
# 2  0.00125      0.333   1.000          3             1         CORUM:6527
# 3  0.02000      0.500   0.200          2             1  REAC:R-HSA-373756
# 4  0.03440      0.016   0.267        243             4         GO:0098742
#
#                                            term.name
# 0                          FLRT3-LPHN3-UNC5D complex
# 1                                FLRT3-LPHN3 complex
# 2                          FLRT3-LPHN3-UNC5B complex
# 3                                   SDK interactions
# 4  cell-cell adhesion via plasma-membrane adhesio...
# 879
# 15
#     p.value  precision  recall  term.size  overlap.size             term.id  \
# 0  0.000012      0.025   0.429        239             6  REAC:R-HSA-5673001
# 1  0.000012      0.027   0.429        221             6   REAC:R-HSA-112315
# 2  0.000012      0.024   0.429        245             6  REAC:R-HSA-5684996
# 3  0.000015      0.200   0.214         15             3   REAC:R-HSA-442729
# 4  0.000015      0.033   0.357        151             5   REAC:R-HSA-112314
#
#                                            term.name
# 0                             RAF/MAP kinase cascade
# 1              Transmission across Chemical Synapses
# 2                              MAPK1/MAPK3 signaling
# 3  CREB phosphorylation through the activation of...
# 4  Neurotransmitter receptors and postsynaptic si...
# 880
# 15
#         p.value  precision  recall  term.size  overlap.size  \
# 0  7.300000e-16      0.018   0.933        768            14
# 1  1.090000e-13      0.012   0.933       1152            14
# 2  2.710000e-10      0.042   0.533        192             8
# 3  4.900000e-10      0.033   0.643        274             9
# 4  4.900000e-10      0.033   0.643        274             9
#
#               term.id                    term.name
# 0          GO:0006325       chromatin organization
# 1          GO:0051276      chromosome organization
# 2          GO:0042393              histone binding
# 3  REAC:R-HSA-4839726       Chromatin organization
# 4  REAC:R-HSA-3247509  Chromatin modifying enzymes
# 881
# 16
#         p.value  precision  recall  term.size  overlap.size  \
# 0  4.940000e-12      0.033   0.818        274             9
# 1  4.940000e-12      0.033   0.818        274             9
# 2  9.950000e-12      0.047   0.562        192             9
# 3  6.430000e-11      0.092   0.438         76             7
# 4  6.840000e-11      0.081   0.438         86             7
#
#               term.id                          term.name
# 0  REAC:R-HSA-3247509        Chromatin modifying enzymes
# 1  REAC:R-HSA-4839726             Chromatin organization
# 2          GO:0042393                    histone binding
# 3          GO:0000123  histone acetyltransferase complex
# 4          GO:1902493          acetyltransferase complex
# 882
# 16
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000003      0.004   0.875       3435            14  GO:0005654
# 1  0.000003      0.003   0.938       4374            15  GO:0044428
# 2  0.000014      0.003   0.875       4026            14  GO:0031981
# 3  0.000154      0.003   0.875       5135            14  GO:0070013
# 4  0.000154      0.003   0.875       5135            14  GO:0031974
#
#                        term.name
# 0                    nucleoplasm
# 1                   nuclear part
# 2                  nuclear lumen
# 3  intracellular organelle lumen
# 4        membrane-enclosed lumen
# 883
# 16
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0   0.0314      0.006     1.0        154             1   REAC:R-HSA-983231
# 1   0.0314      0.012     1.0         81             1  REAC:R-HSA-6811434
# 2   0.0314      0.005     1.0        183             1  REAC:R-HSA-6811442
# 3   0.0314      0.024     1.0         42             1   REAC:R-HSA-983189
# 4   0.0314      0.009     1.0        115             1  REAC:R-HSA-8856688
#
#                                            term.name
# 0  Factors involved in megakaryocyte development ...
# 1      COPI-dependent Golgi-to-ER retrograde traffic
# 2     Intra-Golgi and retrograde Golgi-to-ER traffic
# 3                                           Kinesins
# 4                   Golgi-to-ER retrograde transport
# 884
# 16
#    p.value  precision  recall  term.size  overlap.size      term.id  \
# 0   0.0363      0.018   0.267        221             4  TF:M08406_0
# 1   0.0363      0.009   0.333        527             5    TF:M08444
# 2   0.0363      0.031   0.200         98             3    TF:M07082
# 3   0.0363      0.018   0.267        221             4    TF:M08406
# 4   0.0363      0.031   0.200         98             3  TF:M07082_0
#
#                                            term.name
# 0  Factor: POU2F1:Sox-20; motif: WTGMATAACAAWR; m...
# 1         Factor: AP-4:PEA3; motif: NSCGGAWNCAGNTGNN
# 2                   Factor: DUX4; motif: TAAYYYAATCA
# 3        Factor: POU2F1:Sox-20; motif: WTGMATAACAAWR
# 4   Factor: DUX4; motif: TAAYYYAATCA; match class: 0
# 885
# 17
#     p.value  precision  recall  term.size  overlap.size            term.id  \
# 0  0.000009      0.667   0.667          3             2         CORUM:6527
# 1  0.000199      0.011   0.600        530             6  REAC:R-HSA-422475
# 2  0.000417      0.060   0.300         50             3  REAC:R-HSA-373752
# 3  0.000641      0.200   0.200         10             2  REAC:R-HSA-418889
# 4  0.000641      0.200   0.200         10             2  REAC:R-HSA-418886
#
#                                        term.name
# 0                      FLRT3-LPHN3-UNC5B complex
# 1                                  Axon guidance
# 2                             Netrin-1 signaling
# 3  Ligand-independent caspase activation via DCC
# 4              Netrin mediated repulsion signals
# 886
# 17
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  8.600000e-19      0.040   0.824        348            14  GO:0000790
# 1  1.300000e-16      0.027   0.824        521            14  GO:0000785
# 2  1.330000e-16      0.026   0.824        537            14  GO:0044454
# 3  2.420000e-16      0.024   0.824        572            14  GO:0000228
# 4  6.380000e-15      0.015   0.882       1010            15  GO:0005694
#
#                  term.name
# 0        nuclear chromatin
# 1                chromatin
# 2  nuclear chromosome part
# 3       nuclear chromosome
# 4               chromosome
# 887
# 17
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  5.820000e-19      0.029   0.882        515            15  GO:0003682
# 1  6.540000e-19      0.021   0.941        768            16  GO:0006325
# 2  2.960000e-16      0.014   0.941       1152            16  GO:0051276
# 3  8.960000e-16      0.123   0.529         73             9  GO:0070603
# 4  2.980000e-15      0.025   0.765        521            13  GO:0000785
#
#                           term.name
# 0                 chromatin binding
# 1            chromatin organization
# 2           chromosome organization
# 3  SWI/SNF superfamily-type complex
# 4                         chromatin
# 888
# 17
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000051      0.017   0.412        410             7  GO:0003779
# 1  0.000197      0.009   0.471        879             8  GO:0008092
# 2  0.000197      0.056   0.235         72             4  GO:0016459
# 3  0.000254      0.008   0.471        956             8  GO:0000902
# 4  0.000416      0.008   0.471       1051             8  GO:0032989
#
#                           term.name
# 0                     actin binding
# 1      cytoskeletal protein binding
# 2                    myosin complex
# 3                cell morphogenesis
# 4  cellular component morphogenesis
# 889
# 17
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.00337      0.333     0.5          3             1  CORUM:5461
# 1  0.00337      0.333     0.5          3             1  CORUM:3634
# 2  0.00337      0.333     0.5          3             1   CORUM:786
# 3  0.00337      0.500     0.5          2             1  CORUM:1042
# 4  0.00337      0.333     0.5          3             1  CORUM:6502
#
#                                         term.name
# 0                 p50-p65 NF(kappa)B-SRC1 complex
# 1                        NR3C2-UBC9-SRC-1 complex
# 2                            MR-UBC9-SRC1 complex
# 3             SRA-SRC-1 ribonucleoprotein complex
# 4  Estrogen receptor complex (ESR1, EP300, NCOA1)
# 890
# 17
#         p.value  precision  recall  term.size  overlap.size  \
# 0  7.720000e-07      0.006   0.812       2281            13
# 1  9.020000e-07      0.013   0.778        530             7
# 2  1.200000e-06      0.017   0.500        475             8
# 3  1.590000e-06      0.007   0.688       1535            11
# 4  2.340000e-06      0.667   1.000          3             2
#
#              term.id                   term.name
# 0         GO:0007399  nervous system development
# 1  REAC:R-HSA-422475               Axon guidance
# 2         GO:0061564            axon development
# 3         GO:0022008                neurogenesis
# 4         CORUM:6527   FLRT3-LPHN3-UNC5B complex
# 891
# 18
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0   0.0147      0.009   0.333        549             5  GO:0048667
# 1   0.0147      0.008   0.333        624             5  GO:0048858
# 2   0.0147      0.008   0.333        643             5  GO:0032990
# 3   0.0147      0.008   0.333        622             5  GO:0120039
# 4   0.0147      0.008   0.333        608             5  GO:0048812
#
#                                            term.name
# 0  cell morphogenesis involved in neuron differen...
# 1                      cell projection morphogenesis
# 2                            cell part morphogenesis
# 3  plasma membrane bounded cell projection morpho...
# 4                    neuron projection morphogenesis
# 892
# 18
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  8.560000e-08      0.103   0.429         58             6  KEGG:05213
# 1  2.800000e-07      0.048   0.500        147             7  KEGG:05224
# 2  3.150000e-07      0.042   0.500        165             7  KEGG:05225
# 3  3.150000e-07      0.070   0.429         86             6  KEGG:05210
# 4  4.030000e-07      0.062   0.429         97             6  KEGG:05215
#
#                   term.name
# 0        Endometrial cancer
# 1             Breast cancer
# 2  Hepatocellular carcinoma
# 3         Colorectal cancer
# 4           Prostate cancer
# 893
# 18
#         p.value  precision  recall  term.size  overlap.size  \
# 0  7.730000e-12      0.037   0.750        245             9
# 1  7.730000e-12      0.038   0.750        239             9
# 2  1.970000e-11      0.032   0.750        284             9
# 3  9.370000e-10      0.081   0.500         74             6
# 4  1.440000e-08      0.098   0.417         51             5
#
#               term.id                       term.name
# 0  REAC:R-HSA-5684996           MAPK1/MAPK3 signaling
# 1  REAC:R-HSA-5673001          RAF/MAP kinase cascade
# 2  REAC:R-HSA-5683057  MAPK family signaling cascades
# 3  REAC:R-HSA-6802957        Oncogenic MAPK signaling
# 4  REAC:R-HSA-6802949        Signaling by RAS mutants
# 894
# 20
# 895
# 20
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.270000e-08      0.028    0.45        324             9  GO:0099177
# 1  1.270000e-08      0.028    0.45        323             9  GO:0050804
# 2  4.090000e-08      0.017    0.50        605            10  GO:0007268
# 3  4.090000e-08      0.017    0.50        605            10  GO:0098916
# 4  4.090000e-08      0.013    0.55        853            11  GO:0045202
#
#                                       term.name
# 0        regulation of trans-synaptic signaling
# 1  modulation of chemical synaptic transmission
# 2                chemical synaptic transmission
# 3          anterograde trans-synaptic signaling
# 4                                       synapse
# 896
# 21
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.00234        0.2     1.0          5             1  CORUM:2318
# 1  0.00234        0.2     1.0          5             1  CORUM:2319
#
#                           term.name
# 0  ITGA6-ITGB4-Laminin10/12 complex
# 1  ITGA6-ITGB4-Laminin10/12 complex
# 897
# 21
#         p.value  precision  recall  term.size  overlap.size  \
# 0  1.850000e-36      0.517   0.833         29            15
# 1  2.970000e-27      0.150   0.833        100            15
# 2  1.070000e-21      0.171   0.571         70            12
# 3  1.070000e-21      0.084   0.667        167            14
# 4  1.020000e-20      0.095   0.619        137            13
#
#              term.id                            term.name
# 0  REAC:R-HSA-445095  Interaction between L1 and Ankyrins
# 1  REAC:R-HSA-373760                   L1CAM interactions
# 2         GO:0019226        transmission of nerve impulse
# 3         GO:0035637   multicellular organismal signaling
# 4         GO:0001508                     action potential
# 898
# 22
#         p.value  precision  recall  term.size  overlap.size  \
# 0  2.730000e-25      0.027   0.955        768            21
# 1  7.320000e-22      0.018   0.955       1152            21
# 2  3.020000e-15      0.047   0.684        274            13
# 3  3.020000e-15      0.047   0.684        274            13
# 4  2.230000e-13      0.029   0.591        456            13
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-4839726           Chromatin organization
# 3  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 4          GO:0016569  covalent chromatin modification
# 899
# 22
#         p.value  precision  recall  term.size  overlap.size  \
# 0  9.760000e-08      0.025   0.529        364             9
# 1  1.060000e-06      0.032   0.412        221             7
# 2  1.860000e-06      0.020   0.409        453             9
# 3  8.920000e-06      0.015   0.409        587             9
# 4  9.490000e-06      0.012   0.455        856            10
#
#              term.id                                          term.name
# 0  REAC:R-HSA-112316                                    Neuronal System
# 1  REAC:R-HSA-112315              Transmission across Chemical Synapses
# 2         GO:0046873       metal ion transmembrane transporter activity
# 3         GO:0022890  inorganic cation transmembrane transporter act...
# 4         GO:0030001                                metal ion transport
# 900
# 22
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0   0.0309      0.167   0.333          6             1  REAC:R-HSA-6782861
# 1   0.0322      0.043   0.333         23             1  REAC:R-HSA-2173795
# 2   0.0322      0.077   0.333         13             1  REAC:R-HSA-2892247
# 3   0.0322      0.023   0.333         44             1  REAC:R-HSA-2173793
# 4   0.0322      0.024   0.333         41             1  REAC:R-HSA-6782315
#
#                                            term.name
# 0        Synthesis of wybutosine at G37 of tRNA(Phe)
# 1  Downregulation of SMAD2/3:SMAD4 transcriptiona...
# 2  POU5F1 (OCT4), SOX2, NANOG activate genes rela...
# 3  Transcriptional activity of SMAD2/SMAD3:SMAD4 ...
# 4       tRNA modification in the nucleus and cytosol
# 901
# 22
#    p.value  precision  recall  term.size  overlap.size      term.id  \
# 0  0.00137      0.005   0.636       2837            14  TF:M07397_1
# 1  0.00326      0.004   0.682       3784            15  TF:M07226_1
# 2  0.00468      0.025   0.800        159             4   HP:0010720
# 3  0.00468      0.030   0.800        132             4   HP:0009553
# 4  0.00468      0.028   0.800        145             4   HP:0011361
#
#                                            term.name
# 0  Factor: ZBP89; motif: CCCCKCCCCCNN; match clas...
# 1    Factor: SP1; motif: NCCCCKCCCCC; match class: 1
# 2                              Abnormal hair pattern
# 3                        Abnormality of the hairline
# 4                   Congenital abnormal hair pattern
# 902
# 23
#         p.value  precision  recall  term.size  overlap.size  \
# 0  2.660000e-15      0.160   0.667         50             8
# 1  1.110000e-10      0.019   0.833        530            10
# 2  1.850000e-09      0.010   0.682       1441            15
# 3  2.310000e-09      0.010   0.682       1535            15
# 4  2.530000e-09      0.400   0.333         10             4
#
#              term.id                          term.name
# 0  REAC:R-HSA-373752                 Netrin-1 signaling
# 1  REAC:R-HSA-422475                      Axon guidance
# 2         GO:0048699              generation of neurons
# 3         GO:0022008                       neurogenesis
# 4  REAC:R-HSA-418886  Netrin mediated repulsion signals
# 903
# 23
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000020      0.028     0.3        212             6  GO:0014069
# 1  0.000020      0.028     0.3        213             6  GO:0099572
# 2  0.000020      0.027     0.3        221             6  GO:0098984
# 3  0.000020      0.028     0.3        217             6  GO:0032279
# 4  0.000023      0.025     0.3        236             6  GO:0045211
#
#                      term.name
# 0         postsynaptic density
# 1  postsynaptic specialization
# 2     neuron to neuron synapse
# 3           asymmetric synapse
# 4        postsynaptic membrane
# 904
# 23
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.090000e-17      0.055   0.706        218            12  GO:0016741
# 1  1.090000e-17      0.058   0.706        208            12  GO:0008168
# 2  5.070000e-17      0.065   0.647        168            11  GO:0006479
# 3  5.070000e-17      0.065   0.647        168            11  GO:0008213
# 4  7.760000e-17      0.148   0.529         61             9  GO:0016279
#
#                                            term.name
# 0  transferase activity, transferring one-carbon ...
# 1                         methyltransferase activity
# 2                                protein methylation
# 3                                 protein alkylation
# 4        protein-lysine N-methyltransferase activity
# 905
# 24
#    p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.00421      0.333   0.333          3             1  CORUM:3634
# 1  0.00421      0.333   0.333          3             1  CORUM:6502
# 2  0.00421      0.500   0.333          2             1  CORUM:2759
# 3  0.00421      0.500   0.333          2             1  CORUM:1042
# 4  0.00421      0.333   0.333          3             1  CORUM:2238
#
#                                         term.name
# 0                        NR3C2-UBC9-SRC-1 complex
# 1  Estrogen receptor complex (ESR1, EP300, NCOA1)
# 2                               MBD1-MCAF complex
# 3             SRA-SRC-1 ribonucleoprotein complex
# 4                       MBD1-MCAF1-SETDB1 complex
# 906
# 24
#    p.value  precision  recall  term.size  overlap.size             term.id  \
# 0  0.00187      0.333    1.00          3             1          CORUM:6848
# 1  0.00915      0.500    0.25          2             1   REAC:R-HSA-114294
# 2  0.00915      0.500    0.25          2             1   REAC:R-HSA-111452
# 3  0.01220      0.250    0.25          4             1    REAC:R-HSA-75108
# 4  0.01840      0.077    0.25         13             1  REAC:R-HSA-2892247
#
#                                            term.name
# 0                    IRF2BP2-IRF2BP1-IRF2BPL complex
# 1  Activation, translocation and oligomerization ...
# 2      Activation and oligomerization of BAK protein
# 3  Activation, myristolyation of BID and transloc...
# 4  POU5F1 (OCT4), SOX2, NANOG activate genes rela...
# 907
# 25
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.790000e-17      0.023    0.72        768            18  GO:0006325
# 1  3.270000e-14      0.016    0.72       1152            18  GO:0051276
# 2  8.140000e-13      0.066    0.40        152            10  GO:0018393
# 3  8.140000e-13      0.068    0.40        148            10  GO:0016573
# 4  9.150000e-13      0.063    0.40        158            10  GO:0006475
#
#                                  term.name
# 0                   chromatin organization
# 1                  chromosome organization
# 2     internal peptidyl-lysine acetylation
# 3                      histone acetylation
# 4  internal protein amino acid acetylation
# 908
# 26
#         p.value  precision  recall  term.size  overlap.size  \
# 0  3.040000e-08      0.016   0.522        768            12
# 1  9.060000e-08      0.011   0.565       1152            13
# 2  5.000000e-07      0.029   0.444        274             8
# 3  5.000000e-07      0.029   0.444        274             8
# 4  2.490000e-06      0.023   0.348        348             8
#
#               term.id                    term.name
# 0          GO:0006325       chromatin organization
# 1          GO:0051276      chromosome organization
# 2  REAC:R-HSA-4839726       Chromatin organization
# 3  REAC:R-HSA-3247509  Chromatin modifying enzymes
# 4          GO:0000790            nuclear chromatin
# 909
# 27
#     p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  0.000004      0.068   0.222         88             6  GO:0060996
# 1  0.000007      0.026   0.600        230             6  KEGG:04014
# 2  0.000015      0.044   0.222        136             6  GO:0050773
# 3  0.000015      0.076   0.185         66             5  GO:0060998
# 4  0.000015      0.032   0.259        220             7  GO:0016358
#
#                                    term.name
# 0                dendritic spine development
# 1                      Ras signaling pathway
# 2         regulation of dendrite development
# 3  regulation of dendritic spine development
# 4                       dendrite development
# 910
# 29
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  8.350000e-17      0.025   0.655        768            19  GO:0006325
# 1  8.080000e-14      0.016   0.655       1152            19  GO:0051276
# 2  5.550000e-12      0.066   0.345        152            10  GO:0018393
# 3  5.550000e-12      0.068   0.345        148            10  GO:0016573
# 4  6.230000e-12      0.062   0.345        160            10  GO:0018394
#
#                               term.name
# 0                chromatin organization
# 1               chromosome organization
# 2  internal peptidyl-lysine acetylation
# 3                   histone acetylation
# 4           peptidyl-lysine acetylation
# 911
# 29
# ...
# 0  1.790000e-19      0.022   0.569       1852            41  GO:0006468
# 1  1.790000e-19      0.018   0.653       2622            47  GO:0035556
# 2  1.790000e-19      0.036   0.431        852            31  GO:0000165
# 3  2.410000e-19      0.036   0.431        869            31  GO:0023014
# 4  1.810000e-18      0.011   0.861       5833            62  GO:0007165
#
#                                         term.name
# 0                         protein phosphorylation
# 1               intracellular signal transduction
# 2                                    MAPK cascade
# 3  signal transduction by protein phosphorylation
# 4                             signal transduction
# 943
# 74
#         p.value  precision  recall  term.size  overlap.size  \
# 0  3.880000e-65      0.077   0.808        768            59
# 1  1.130000e-56      0.052   0.822       1152            60
# 2  3.050000e-42      0.131   0.655        274            36
# 3  3.050000e-42      0.131   0.655        274            36
# 4  3.770000e-37      0.081   0.507        456            37
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 3  REAC:R-HSA-4839726           Chromatin organization
# 4          GO:0016569  covalent chromatin modification
# 944
# 77
#         p.value  precision  recall  term.size  overlap.size  \
# 0  3.090000e-16      0.017   0.592       2622            45
# 1  3.090000e-16      0.034   0.382        852            29
# 2  3.480000e-16      0.033   0.382        869            29
# 3  7.020000e-14      0.073   0.321        245            18
# 4  3.210000e-13      0.063   0.321        284            18
#
#               term.id                                       term.name
# 0          GO:0035556               intracellular signal transduction
# 1          GO:0000165                                    MAPK cascade
# 2          GO:0023014  signal transduction by protein phosphorylation
# 3  REAC:R-HSA-5684996                           MAPK1/MAPK3 signaling
# 4  REAC:R-HSA-5683057                  MAPK family signaling cascades
# 945
# 82
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.080000e-12      0.017   0.526       2475            41  GO:0009653
# 1  1.590000e-12      0.022   0.410       1441            32  GO:0048699
# 2  2.160000e-12      0.019   0.462       1942            36  GO:0006928
# 3  2.600000e-12      0.010   0.756       5833            59  GO:0007165
# 4  3.830000e-12      0.021   0.410       1535            32  GO:0022008
#
#                                    term.name
# 0         anatomical structure morphogenesis
# 1                      generation of neurons
# 2  movement of cell or subcellular component
# 3                        signal transduction
# 4                               neurogenesis
# 946
# 92
#         p.value  precision  recall  term.size  overlap.size  \
# 0  8.290000e-26      0.552   0.219         29            16
# 1  8.850000e-21      0.190   0.260        100            19
# 2  9.940000e-21      0.035   0.440       1155            40
# 3  9.940000e-21      0.126   0.231        167            21
# 4  2.270000e-20      0.055   0.330        549            30
#
#              term.id                                          term.name
# 0  REAC:R-HSA-445095                Interaction between L1 and Ankyrins
# 1  REAC:R-HSA-373760                                 L1CAM interactions
# 2         GO:0043005                                  neuron projection
# 3         GO:0035637                 multicellular organismal signaling
# 4         GO:0048667  cell morphogenesis involved in neuron differen...
# 947
# 94
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  9.560000e-18      0.017   0.634       3435            59  GO:0005654
# 1  9.650000e-17      0.015   0.688       4374            64  GO:0044428
# 2  3.350000e-16      0.011   0.839       7066            78  GO:0005634
# 3  1.220000e-15      0.015   0.645       4026            60  GO:0031981
# 4  3.150000e-14      0.036   0.301        768            28  GO:0006325
#
#                 term.name
# 0             nucleoplasm
# 1            nuclear part
# 2                 nucleus
# 3           nuclear lumen
# 4  chromatin organization
# 948
# 96
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.900000e-19      0.016   0.719       4374            69  GO:0044428
# 1  1.360000e-18      0.018   0.635       3435            61  GO:0005654
# 2  9.130000e-17      0.016   0.656       4026            63  GO:0031981
# 3  2.940000e-16      0.011   0.833       7066            80  GO:0005634
# 4  2.190000e-14      0.018   0.521       2752            50  GO:0009892
#
#                                   term.name
# 0                              nuclear part
# 1                               nucleoplasm
# 2                             nuclear lumen
# 3                                   nucleus
# 4  negative regulation of metabolic process
# 949
# 108
#         p.value  precision  recall  term.size  overlap.size  \
# 0  4.870000e-41      0.069   0.500        768            53
# 1  1.940000e-35      0.092   0.387        446            41
# 2  3.230000e-35      0.090   0.387        456            41
# 3  5.900000e-35      0.048   0.519       1152            55
# 4  7.370000e-34      0.124   0.493        274            34
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0016570             histone modification
# 2          GO:0016569  covalent chromatin modification
# 3          GO:0051276          chromosome organization
# 4  REAC:R-HSA-4839726           Chromatin organization
# 950
# 109
#          p.value  precision  recall  term.size  overlap.size  \
# 0  8.940000e-108      0.120   0.852        768            92
# 1   3.500000e-91      0.080   0.852       1152            92
# 2   4.950000e-81      0.237   0.691        274            65
# 3   4.950000e-81      0.237   0.691        274            65
# 4   1.760000e-68      0.136   0.574        456            62
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-4839726           Chromatin organization
# 3  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 4          GO:0016569  covalent chromatin modification
# 951
# 110
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.610000e-25      0.052   0.392        768            40  GO:0006325
# 1  7.920000e-22      0.037   0.422       1152            43  GO:0051276
# 2  3.800000e-18      0.013   0.784       5973            80  GO:0016043
# 3  1.990000e-17      0.017   0.618       3634            63  GO:1903506
# 4  1.990000e-17      0.013   0.784       6146            80  GO:0071840
#
#                                            term.name
# 0                             chromatin organization
# 1                            chromosome organization
# 2                    cellular component organization
# 3  regulation of nucleic acid-templated transcrip...
# 4      cellular component organization or biogenesis
# 952
# 119
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.280000e-22      0.022   0.632       3435            74  GO:0005654
# 1  4.880000e-21      0.018   0.684       4374            80  GO:0044428
# 2  8.650000e-21      0.049   0.325        768            38  GO:0006325
# 3  1.980000e-20      0.019   0.650       4026            76  GO:0031981
# 4  1.720000e-19      0.037   0.368       1152            43  GO:0051276
#
#                  term.name
# 0              nucleoplasm
# 1             nuclear part
# 2   chromatin organization
# 3            nuclear lumen
# 4  chromosome organization
# 953
# 134
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  7.640000e-27      0.031   0.547       2281            70  GO:0007399
# 1  1.440000e-26      0.073   0.312        549            40  GO:0048667
# 2  1.690000e-25      0.082   0.281        438            36  GO:0007409
# 3  3.700000e-25      0.066   0.312        608            40  GO:0048812
# 4  4.690000e-25      0.037   0.445       1535            57  GO:0022008
#
#                                            term.name
# 0                         nervous system development
# 1  cell morphogenesis involved in neuron differen...
# 2                                       axonogenesis
# 3                    neuron projection morphogenesis
# 4                                       neurogenesis
# 954
# 144
#          p.value  precision  recall  term.size  overlap.size  \
# 0  9.610000e-133      0.151   0.817        768           116
# 1  2.300000e-113      0.102   0.824       1152           117
# 2   1.500000e-95      0.281   0.675        274            77
# 3   1.500000e-95      0.281   0.675        274            77
# 4   3.490000e-83      0.169   0.542        456            77
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-4839726           Chromatin organization
# 3  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 4          GO:0016569  covalent chromatin modification
# 955
# 177
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  3.060000e-33      0.074   0.345        768            57  GO:0006325
# 1  5.110000e-27      0.052   0.364       1152            60  GO:0051276
# 2  9.040000e-23      0.026   0.570       3642            94  GO:2001141
# 3  9.040000e-23      0.026   0.570       3634            94  GO:1903506
# 4  2.020000e-22      0.026   0.564       3611            93  GO:0006355
#
#                                            term.name
# 0                             chromatin organization
# 1                            chromosome organization
# 2             regulation of RNA biosynthetic process
# 3  regulation of nucleic acid-templated transcrip...
# 4         regulation of transcription, DNA-templated
# 956
# 191
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  2.520000e-52      0.100   0.407        768            77  GO:0006325
# 1  4.690000e-47      0.073   0.444       1152            84  GO:0051276
# 2  2.980000e-44      0.037   0.667       3435           126  GO:0005654
# 3  1.490000e-39      0.031   0.709       4374           134  GO:0044428
# 4  2.270000e-39      0.032   0.683       4026           129  GO:0031981
#
#                  term.name
# 0   chromatin organization
# 1  chromosome organization
# 2              nucleoplasm
# 3             nuclear part
# 4            nuclear lumen
# 957
# 206
#          p.value  precision  recall  term.size  overlap.size  \
# 0  1.010000e-135      0.174   0.684        768           134
# 1  2.700000e-114      0.118   0.694       1152           136
# 2   1.020000e-99      0.307   0.618        274            84
# 3   1.020000e-99      0.307   0.618        274            84
# 4   1.090000e-87      0.195   0.454        456            89
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-4839726           Chromatin organization
# 3  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 4          GO:0016569  covalent chromatin modification
# 958
# 220
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  5.640000e-35      0.045   0.495       2281           102  GO:0007399
# 1  6.750000e-32      0.053   0.398       1535            82  GO:0022008
# 2  2.140000e-31      0.055   0.383       1441            79  GO:0048699
# 3  3.790000e-30      0.089   0.262        608            54  GO:0048812
# 4  8.130000e-30      0.087   0.262        622            54  GO:0120039
#
#                                            term.name
# 0                         nervous system development
# 1                                       neurogenesis
# 2                              generation of neurons
# 3                    neuron projection morphogenesis
# 4  plasma membrane bounded cell projection morpho...
# 959
# 240
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  4.260000e-57      0.116   0.374        768            89  GO:0006325
# 1  1.090000e-51      0.045   0.647       3435           154  GO:0005654
# 2  1.220000e-50      0.084   0.408       1152            97  GO:0051276
# 3  7.450000e-47      0.039   0.668       4026           159  GO:0031981
# 4  3.700000e-46      0.037   0.689       4374           164  GO:0044428
#
#                  term.name
# 0   chromatin organization
# 1              nucleoplasm
# 2  chromosome organization
# 3            nuclear lumen
# 4             nuclear part
# 960
# 302
#          p.value  precision  recall  term.size  overlap.size  \
# 0  1.890000e-110      0.180   0.486        768           138
# 1   1.020000e-90      0.123   0.500       1152           142
# 2   3.160000e-82      0.307   0.438        274            84
# 3   3.160000e-82      0.307   0.438        274            84
# 4   5.420000e-73      0.200   0.320        456            91
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1          GO:0051276          chromosome organization
# 2  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 3  REAC:R-HSA-4839726           Chromatin organization
# 4          GO:0016569  covalent chromatin modification
# 961
# 324
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  1.810000e-31      0.053   0.407       2281           122  GO:0007399
# 1  3.060000e-30      0.066   0.317       1441            95  GO:0048699
# 2  3.060000e-30      0.064   0.327       1535            98  GO:0022008
# 3  1.890000e-28      0.068   0.293       1303            88  GO:0030182
# 4  9.020000e-27      0.099   0.200        608            60  GO:0048812
#
#                          term.name
# 0       nervous system development
# 1            generation of neurons
# 2                     neurogenesis
# 3           neuron differentiation
# 4  neuron projection morphogenesis
# 962
# 344
#         p.value  precision  recall  term.size  overlap.size     term.id  \
# 0  5.980000e-79      0.160   0.364        768           123  GO:0006325
# 1  4.150000e-67      0.115   0.391       1152           132  GO:0051276
# 2  6.340000e-67      0.061   0.621       3435           210  GO:0005654
# 3  8.950000e-62      0.054   0.648       4026           219  GO:0031981
# 4  8.950000e-62      0.193   0.260        456            88  GO:0016569
#
#                          term.name
# 0           chromatin organization
# 1          chromosome organization
# 2                      nucleoplasm
# 3                    nuclear lumen
# 4  covalent chromatin modification
# 963
# 844
#         p.value  precision  recall  term.size  overlap.size  \
# 0  7.350000e-77      0.228   0.225        768           175
# 1  6.470000e-65      0.358   0.226        274            98
# 2  6.470000e-65      0.358   0.226        274            98
# 3  3.050000e-60      0.268   0.157        456           122
# 4  3.830000e-59      0.164   0.243       1152           189
#
#               term.id                        term.name
# 0          GO:0006325           chromatin organization
# 1  REAC:R-HSA-3247509      Chromatin modifying enzymes
# 2  REAC:R-HSA-4839726           Chromatin organization
# 3          GO:0016569  covalent chromatin modification
# 4          GO:0051276          chromosome organization

# %%
cluster2top_pathway.head()
cluster2top_pathway.index=cluster2top_pathway['cluster']
cluster2top_pathway.head()
# Out:
#         cluster num_genes_in_cluster  \
# cluster
# 844         844                    6
# 845         845                    7
# 846         846                    7
# 847         847                    8
# 848         848                    8
#
#                                                    pathway  \
# cluster
# 844                   voltage-gated sodium channel complex
# 845      Trafficking of myristoylated proteins to the c...
# 846            histone-lysine N-methyltransferase activity
# 847                                        hsa-miR-6789-3p
# 848         Intra-Golgi and retrograde Golgi-to-ER traffic
#
#                        term_ID  term_p-value term_precision term_recall
# cluster
# 844                 GO:0001518  1.820000e-13          0.357       0.833
# 845         REAC:R-HSA-5624138  2.710000e-02            0.2       0.333
# 846                 GO:0018024  2.150000e-16          0.149           1
# 847      MIRNA:hsa-miR-6789-3p  2.700000e-02           0.03         0.4
# 848         REAC:R-HSA-6811442  3.140000e-02          0.005           1

# %% [markdown]
# # add top gprofiler term per cluster for further analysis/ visualization in cytoscape

# %%
# add top pathway to ont2numVal
ont2numVal=ont2numVal.join(cluster2top_pathway[['num_genes_in_cluster','term_p-value',
                                                'term_precision','term_recall','pathway','term_ID']])

# %%
ont2numVal.to_csv('new_clixo_files/ont2numVal_cosine_alpha'+alpha+'_beta'+beta+'.txt',sep='\t')
# load precomputed ont2numVal so we don't have to enrich each pathway again
# ont2numVal = pd.read_csv('new_clixo_files/ont2numVal_cosine_alpha'+alpha+'_beta'+beta+'.txt',sep='\t',index_col='term')
# ont2numVal.head()

# %%
ont2numVal.head()
# Out:
#      all_val_genes cluster_size num_DECIPHER_CNV num_DECIPHER_SNV  \
# term
# 886              9           17                4                4
# 920             19           37                5               13
# 892              9           18                3                7
# 853              4            9                2                4
# 852              4            9                2                2
#
#      num_shared_DNV term fractionVal num_genes_in_cluster  term_p-value  \
# term
# 886               3  886    0.529412                   17  8.600000e-19
# 920               9  920    0.513514                   37  5.480000e-13
# 892               3  892         0.5                   18  8.560000e-08
# 853               2  853    0.444444                    9  3.450000e-10
# 852               2  852    0.444444                    9  1.120000e-14
#
#      term_precision term_recall  \
# term
# 886            0.04       0.824
# 920           0.172       0.357
# 892           0.103       0.429
# 853           0.012           1
# 852           0.353       0.667
#
#                                                 pathway            term_ID
# term
# 886                                   nuclear chromatin         GO:0000790
# 920                                  Endometrial cancer         KEGG:05213
# 892                                  Endometrial cancer         KEGG:05213
# 853                              chromatin organization         GO:0006325
# 852   Ras activation upon Ca2+ influx through NMDA r...  REAC:R-HSA-442982

# %% [markdown]
# # write out ontology to cytoscape compatible format

# %%
# used to use the full ontology, but now we use the tree form for plotting
# ont.to_table('../clixo_hierarchy/new_clixo_no_alignment/ASD_CHD_cosine_'+alpha+'_'+beta+'.txt')

# %%
# write out ontology in tree form (this is what is used in making the figures)
tree = ont.get_tree()
tree_df = pd.DataFrame(zip(*tree)).T
tree_df.columns=['child','parent']
tree_df.to_csv('new_clixo_files/tree_ASDCHD_cosine_'+alpha+'_'+beta+'.csv')
tree_df.head()
# Out:
#      child parent
# 0  PLEKHA7    861
# 1  FAM126A    963
# 2      ISX    874
# 3    SNTG2    953
# 4    PALM2    850
