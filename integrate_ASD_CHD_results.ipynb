# %% [markdown]
# # Integrate the results from various other notebooks (DDD, DECIPHER, DNVs), and prep for cytoscape visualization

# %%
import matplotlib
matplotlib.use('TkAgg')

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pandas as pd
import random

import community

from scipy.stats import mannwhitneyu

import mygene
mg = mygene.MyGeneInfo()

# latex rendering of text in graphs
import matplotlib as mpl
mpl.rc('text', usetex = False)
mpl.rc('font', family = 'serif')

sns.set_style('white')

import sys

import visJS2jupyter.visJS_module
import visJS2jupyter.visualizations


% matplotlib inline

# %% [markdown]
# # Load the DDD and DECIPHER results

# %%
DDD_df = pd.read_csv('../../manuscript/tables_18_02/DDD_in_ASD_CHD_interactome.tsv',sep='\t',names=['gene','num_DDD_patients'],
                    index_col='gene')
DDD_df.head()
# Out:
#          num_DDD_patients
# gene
# ANKRD11                41
# KMT2A                  35
# CTNNB1                 18
# MED13L                 16
# KAT6B                  13

# %%
decipher_df = pd.read_excel('../../manuscript/tables_18_02/G_ASD_CHD_GIANT_p2nodes_180313.xlsx',sheetname='G_ASD_CHD_GIANT_p2nodes',
                           dtype={'gene':str},index_col='gene')

decipher_df.head()
# Out:
#          number shared phenotype patients with a mutation in this gene in decipher database (DNV)  \
# gene
# CTTNBP2                                                NaN
# USP45                                                  NaN
# SHANK3                                                 NaN
# NAA15                                                  NaN
# MYH6                                                   NaN
#
#          number shared phenotype patients explained (with seeds, DNV)  \
# gene
# CTTNBP2                                                0.0
# USP45                                                  0.0
# SHANK3                                                 4.0
# NAA15                                                  5.0
# MYH6                                                   5.0
#
#          num shared phenotype patients explained (no seeds, DNV)  \
# gene
# CTTNBP2                                                NaN
# USP45                                                  NaN
# SHANK3                                                 NaN
# NAA15                                                  NaN
# MYH6                                                   NaN
#
#          number shared phenotype patients explained (with seeds, all variants)  \
# gene
# CTTNBP2                                                1.0
# USP45                                                  2.0
# SHANK3                                                 9.0
# NAA15                                                 11.0
# MYH6                                                  12.0
#
#          num shared phenotype patients explained (no seeds, all variants)  \
# gene
# CTTNBP2                                                NaN
# USP45                                                  NaN
# SHANK3                                                 NaN
# NAA15                                                  NaN
# MYH6                                                   NaN
#
#          ASD_CHD_DNV  ASD_HC  CHD_HC      z_ASD      z_CHD     z_both  \
# gene
# CTTNBP2            0       1       0  47.350731   1.195295  27.753490
# USP45              0       1       0  30.431117   0.066237  21.539680
# SHANK3             0       1       0  24.601011   2.211072  16.876845
# NAA15              0       1       1  14.023218   9.630552  15.035266
# MYH6               0       0       1   0.865649  18.513572  14.645288
#
#              xpos      ypos
# gene
# CTTNBP2 -1.538416 -0.377440
# USP45   -1.293820 -0.194478
# SHANK3  -1.587422  0.254440
# NAA15   -0.161088  1.309620
# MYH6     1.738860  0.469920

# %%
combined_df = decipher_df[['number shared phenotype patients with a mutation in this gene in decipher database (DNV)',
                          'ASD_CHD_DNV','ASD_HC','CHD_HC','z_ASD','z_CHD','z_both']]
combined_df.columns=['num_decipher_patients','ASD_CHD_DNV','ASD_HC','CHD_HC','z_ASD','z_CHD','z_both'] # rename the columns so they are more manageable


combined_df.head()
# Out:
#          num_decipher_patients  ASD_CHD_DNV  ASD_HC  CHD_HC      z_ASD  \
# gene
# CTTNBP2                    NaN            0       1       0  47.350731
# USP45                      NaN            0       1       0  30.431117
# SHANK3                     NaN            0       1       0  24.601011
# NAA15                      NaN            0       1       1  14.023218
# MYH6                       NaN            0       0       1   0.865649
#
#              z_CHD     z_both
# gene
# CTTNBP2   1.195295  27.753490
# USP45     0.066237  21.539680
# SHANK3    2.211072  16.876845
# NAA15     9.630552  15.035266
# MYH6     18.513572  14.645288

# %%
# add DDD colum
combined_df['DDD_variant']=np.zeros(len(combined_df))
combined_df['DDD_variant'].loc[DDD_df.index.tolist()]=DDD_df['num_DDD_patients']
combined_df.head()
# Out:
# /Users/brin/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/brin/anaconda/lib/python2.7/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/brin/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          num_decipher_patients  ASD_CHD_DNV  ASD_HC  CHD_HC      z_ASD  \
# gene
# CTTNBP2                    NaN            0       1       0  47.350731
# USP45                      NaN            0       1       0  30.431117
# SHANK3                     NaN            0       1       0  24.601011
# NAA15                      NaN            0       1       1  14.023218
# MYH6                       NaN            0       0       1   0.865649
#
#              z_CHD     z_both  DDD_variant
# gene
# CTTNBP2   1.195295  27.753490          0.0
# USP45     0.066237  21.539680          0.0
# SHANK3    2.211072  16.876845          0.0
# NAA15     9.630552  15.035266          0.0
# MYH6     18.513572  14.645288          0.0

# %%
sum(combined_df['DDD_variant'])
# Out:
# 407.0

# %%
# add the piechart and circos plot data
combined_df['has_DDD_variant']=(combined_df['DDD_variant']>0)*1.0
combined_df['has_decipher_variant']=(combined_df['num_decipher_patients']>0)*1.0

# make a piechart for the DDD, decipher, and DNV columns
combined_df['piechart_data']=['piechart: attributelist="has_DDD_variant,has_decipher_variant,ASD_CHD_DNV" colorlist="red,yellow,blue" showlabels=false']*len(combined_df)

#combined_df.to_csv('combined_DDD_DECIPHER_ASD_CHD_node_table.csv')

combined_df.head()
# Out:
# /Users/brin/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/brin/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/brin/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#          num_decipher_patients  ASD_CHD_DNV  ASD_HC  CHD_HC      z_ASD  \
# gene
# CTTNBP2                    NaN            0       1       0  47.350731
# USP45                      NaN            0       1       0  30.431117
# SHANK3                     NaN            0       1       0  24.601011
# NAA15                      NaN            0       1       1  14.023218
# MYH6                       NaN            0       0       1   0.865649
#
#              z_CHD     z_both  DDD_variant  has_DDD_variant  \
# gene
# CTTNBP2   1.195295  27.753490          0.0              0.0
# USP45     0.066237  21.539680          0.0              0.0
# SHANK3    2.211072  16.876845          0.0              0.0
# NAA15     9.630552  15.035266          0.0              0.0
# MYH6     18.513572  14.645288          0.0              0.0
#
#          has_decipher_variant  \
# gene
# CTTNBP2                   0.0
# USP45                     0.0
# SHANK3                    0.0
# NAA15                     0.0
# MYH6                      0.0
#
#                                              piechart_data
# gene
# CTTNBP2  piechart: attributelist="has_DDD_variant,has_d...
# USP45    piechart: attributelist="has_DDD_variant,has_d...
# SHANK3   piechart: attributelist="has_DDD_variant,has_d...
# NAA15    piechart: attributelist="has_DDD_variant,has_d...
# MYH6     piechart: attributelist="has_DDD_variant,has_d...

# %%
sum(combined_df['ASD_CHD_DNV'])
# Out:
# 41

# %%
combined_df.dropna()[['num_decipher_patients','DDD_variant']].sort_values('DDD_variant',ascending=False).head(15)
# Out:
#          num_decipher_patients  DDD_variant
# gene
# ANKRD11                   10.0         41.0
# CTNNB1                     0.0         18.0
# MED13L                     7.0         16.0
# KAT6B                      3.0         13.0
# EP300                      9.0         13.0
# KAT6A                      7.0          9.0
# SATB2                      3.0          9.0
# KANSL1                     7.0          9.0
# SRRM2                      0.0          5.0
# TCF12                      4.0          4.0
# MEIS2                      4.0          4.0
# SPEN                       1.0          4.0
# CREBBP                     8.0          3.0
# EBF3                       3.0          3.0
# BAZ2B                      1.0          3.0

# %%
# print out the genes with 2 of DDD, Decipher, DNV and no seeds, for pathway enrichment
multi_evidence_genes = combined_df[(combined_df['has_DDD_variant']+combined_df['has_decipher_variant']+combined_df['ASD_CHD_DNV'])>1]

# remove seeds
multi_evidence_genes = multi_evidence_genes[(multi_evidence_genes['ASD_HC']+multi_evidence_genes['CHD_HC'])==0]

print(len(multi_evidence_genes))
multi_evidence_genes.head()
# Out:
# 42
#          num_decipher_patients  ASD_CHD_DNV  ASD_HC  CHD_HC     z_ASD  \
# gene
# EBF3                       3.0            0       0       0  3.590142
# EP300                      9.0            1       0       0  3.261691
# CTNNB1                     0.0            1       0       0  3.087033
# ZBTB20                     1.0            0       0       0  3.046547
# KANSL1L                    1.0            0       0       0  3.206343
#
#             z_CHD    z_both  DDD_variant  has_DDD_variant  \
# gene
# EBF3     3.357178  4.826389          3.0              1.0
# EP300    3.033605  4.335350         13.0              1.0
# CTNNB1   3.142416  4.288727         18.0              1.0
# ZBTB20   2.448150  4.016793          1.0              1.0
# KANSL1L  2.351072  3.774944          1.0              1.0
#
#          has_decipher_variant  \
# gene
# EBF3                      1.0
# EP300                     1.0
# CTNNB1                    0.0
# ZBTB20                    1.0
# KANSL1L                   1.0
#
#                                              piechart_data
# gene
# EBF3     piechart: attributelist="has_DDD_variant,has_d...
# EP300    piechart: attributelist="has_DDD_variant,has_d...
# CTNNB1   piechart: attributelist="has_DDD_variant,has_d...
# ZBTB20   piechart: attributelist="has_DDD_variant,has_d...
# KANSL1L  piechart: attributelist="has_DDD_variant,has_d...

# %%
for g in multi_evidence_genes.index.tolist():
    print(g)
# Out:
# EBF3
# EP300
# CTNNB1
# ZBTB20
# KANSL1L
# VPS13D
# PCDHA12
# ETS1
# MED13L
# SALL3
# KANSL1
# VEZF1
# DMXL2
# CRB1
# ZMYM2
# BPTF
# CREBBP
# BAZ2B
# USP34
# BRWD3
# HECW2
# SPEN
# ANKHD1-EIF4EBP3
# SATB2
# SOS1
# ZFC3H1
# ZNF462
# ANKRD11
# KAT6A
# BRD4
# PPP1R12A
# TCF12
# CTBP2
# UBR3
# PCBP2
# MEIS2
# TLK2
# KAT6B
# SRRM2
# SPRY1
# NF1
# SIPA1L1

# %%
#combined_df.dropna().to_csv('../combined_DDD_DECIPHER_ASD_CHD_node_table_no_seeds.csv')
